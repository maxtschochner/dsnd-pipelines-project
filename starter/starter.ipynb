# %% [markdown]
# # Pipeline Project

# %% [markdown]
# You will be using the provided data to create a machine learning model pipeline.
#
# You must handle the data appropriately in your pipeline to predict whether an
# item is recommended by a customer based on their review.
# Note the data includes numerical, categorical, and text data.
#
# You should ensure you properly train and evaluate your model.

# %% [markdown]
# ## Loads & Imports

# %% [markdown]
# ### Loads

# %%
# ! python -m spacy download en_core_web_sm
# ! python -m textblob.download_corpora

# %% [markdown]
# ### Imports

# %%
# general
import pandas as pd
import numpy as np

# spaCy
import spacy
from spacy.tokens import Doc
nlp = spacy.load('en_core_web_sm')
from spacytextblob.spacytextblob import SpacyTextBlob
nlp.add_pipe('spacytextblob')

# sklearn
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import FunctionTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ## The Data

# %% [markdown]
# The dataset has been anonymized and cleaned of missing values.
#
# There are 8 features for to use to predict whether a customer recommends or does
# not recommend a product.
# The `Recommended IND` column gives whether a customer recommends the product
# where `1` is recommended and a `0` is not recommended.
# This is your model's target/

# %% [markdown]
# The features can be summarized as the following:
#
# - **Clothing ID**: Integer Categorical variable that refers to the specific piece being reviewed.
# - **Age**: Positive Integer variable of the reviewers age.
# - **Title**: String variable for the title of the review.
# - **Review Text**: String variable for the review body.
# - **Positive Feedback Count**: Positive Integer documenting the number of other customers who found this review positive.
# - **Division Name**: Categorical name of the product high level division.
# - **Department Name**: Categorical name of the product department name.
# - **Class Name**: Categorical name of the product class name.
#
# The target:
# - **Recommended IND**: Binary variable stating where the customer recommends the product where 1 is recommended, 0 is not recommended.

# %% [markdown]
# ## Load Data

# %%
# Load data
df = pd.read_csv(
    'data/reviews.csv',
)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18442 entries, 0 to 18441
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Clothing ID              18442 non-null  int64
#  1   Age                      18442 non-null  int64
#  2   Title                    18442 non-null  object
#  3   Review Text              18442 non-null  object
#  4   Positive Feedback Count  18442 non-null  int64
#  5   Division Name            18442 non-null  object
#  6   Department Name          18442 non-null  object
#  7   Class Name               18442 non-null  object
#  8   Recommended IND          18442 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.3+ MB
#    Clothing ID  Age                    Title  \
# 0         1077   60  Some major design flaws
# 1         1049   50         My favorite buy!
# 2          847   47         Flattering shirt
# 3         1080   49  Not for the very petite
# 4          858   39     Cagrcoal shimmer fun
#
#                                          Review Text  Positive Feedback Count  \
# 0  I had such high hopes for this dress and reall...                        0
# 1  I love, love, love this jumpsuit. it's fun, fl...                        0
# 2  This shirt is very flattering to all due to th...                        6
# 3  I love tracy reese dresses, but this one is no...                        4
# 4  I aded this in my basket at hte last mintue to...                        1
#
#     Division Name Department Name Class Name  Recommended IND
# 0         General         Dresses    Dresses                0
# 1  General Petite         Bottoms      Pants                1
# 2         General            Tops    Blouses                1
# 3         General         Dresses    Dresses                0
# 4  General Petite            Tops      Knits                1

# %% [markdown]
# ## Preparing features (`X`) & target (`y`)

# %%
data = df

# separate features from labels
X = data.drop('Recommended IND', axis=1)
y = data['Recommended IND'].copy()

print('Labels:', y.unique())
print('Features:')
display(X.head())
# Out:
# Labels: [0 1]
# Features:
#    Clothing ID  Age                    Title  \
# 0         1077   60  Some major design flaws
# 1         1049   50         My favorite buy!
# 2          847   47         Flattering shirt
# 3         1080   49  Not for the very petite
# 4          858   39     Cagrcoal shimmer fun
#
#                                          Review Text  Positive Feedback Count  \
# 0  I had such high hopes for this dress and reall...                        0
# 1  I love, love, love this jumpsuit. it's fun, fl...                        0
# 2  This shirt is very flattering to all due to th...                        6
# 3  I love tracy reese dresses, but this one is no...                        4
# 4  I aded this in my basket at hte last mintue to...                        1
#
#     Division Name Department Name Class Name
# 0         General         Dresses    Dresses
# 1  General Petite         Bottoms      Pants
# 2         General            Tops    Blouses
# 3         General         Dresses    Dresses
# 4  General Petite            Tops      Knits

# %%
# Split data into train and test sets

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.1,
    shuffle=True,
    random_state=27,
)

# %% [markdown]
# # Your Work

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Explore Unique Values of Categorical Features

# %%
print(f'Division Names: {X['Division Name'].unique()}')
print(f'Department Names: {X['Department Name'].unique()}')
print(f'Class Names: {X['Class Name'].unique()}')
# Out:
# Division Names: ['General' 'General Petite']
# Department Names: ['Dresses' 'Bottoms' 'Tops' 'Jackets' 'Trend' 'Intimate']
# Class Names: ['Dresses' 'Pants' 'Blouses' 'Knits' 'Outerwear' 'Sweaters' 'Skirts'
#  'Fine gauge' 'Jackets' 'Trend' 'Lounge' 'Jeans' 'Shorts' 'Casual bottoms']

# %% [markdown]
# ### Explored Combined Unique Values

# %%
print(f'Combinations:\n{X[['Class Name', 'Department Name', 'Division Name']].drop_duplicates().to_string(index=False)}')

count_combined_unique = len(X[['Class Name', 'Department Name', 'Division Name']].drop_duplicates())

print(f'\nCombined unique values: {count_combined_unique}')
# Out:
# Combinations:
#     Class Name Department Name  Division Name
#        Dresses         Dresses        General
#          Pants         Bottoms General Petite
#        Blouses            Tops        General
#          Knits            Tops General Petite
#        Dresses         Dresses General Petite
#          Pants         Bottoms        General
#      Outerwear         Jackets        General
#       Sweaters            Tops        General
#         Skirts         Bottoms        General
#     Fine gauge            Tops        General
#          Knits            Tops        General
#        Blouses            Tops General Petite
#        Jackets         Jackets        General
#         Skirts         Bottoms General Petite
#          Trend           Trend        General
#     Fine gauge            Tops General Petite
#         Lounge        Intimate General Petite
#          Jeans         Bottoms        General
#        Jackets         Jackets General Petite
#       Sweaters            Tops General Petite
#          Jeans         Bottoms General Petite
#         Shorts         Bottoms        General
#          Trend           Trend General Petite
#      Outerwear         Jackets General Petite
# Casual bottoms         Bottoms        General
#
# Combined unique values: 25

# %% [markdown]
# ### Explore Clothing ID

# %%
print(f'Unique Clothing IDs: {len(X['Clothing ID'].unique())}')
print(f'Total Number of Clothing IDs: {len(X['Clothing ID'])}')
# Out:
# Unique Clothing IDs: 531
# Total Number of Clothing IDs: 18442

# %% [markdown]
# --> Clothing ID also characterizes certain items.
#
# Sorting by Clothing ID and looking at head and tail.

# %%
X.sort_values('Clothing ID').head(20)
# Out:
#        Clothing ID  Age                              Title  \
# 670              2   28  Gorgeous top, straps way too long
# 23               4   28               Great layering piece
# 4833             5   39                   Oldie but goodie
# 17913            7   39       Four winters in... a winner!
# 15259            9   34                      Okay leggings
# 12145           11   46                  Wanted to love it
# 8702            12   28              Beautiful staple item
# 5502            13   39                Stylish but strange
# 15827           16   39                           Gorgeous
# 6482            17   31                   Love this dress!
# 2004            18   42              Disappointing quality
# 14204           19   21     Should've gotten a larger size
# 2229            20   34                 Classy black dress
# 2136            21   55                     Love love love
# 8512            22   30    Please bring this shirt back!!!
# 11088           25   38                  Adorable and cozy
# 13102           26   34                 Cute holiday dress
# 13800           29   26               Perfect fit an flare
# 5855            30   36                         Runs large
# 9756            45   26             Cute pants, but short.
#
#                                              Review Text  \
# 670    I just adore this top! it is so comfy and styl...
# 23     This sweater is so comfy and classic - it bala...
# 4833   I'm currently on the prowl for the other color...
# 17913  I love this coat. i bought it in 2012, and it ...
# 15259  The velvet isn't as soft or plush as i thought...
# 12145  The color says red but it's more like a rust. ...
# 8702   Love this striped top! it's perfect to throw o...
# 5502   I love the color, the fabric and the style (es...
# 15827  This gorgeous dress really does bloom before y...
# 6482   I absolutely love this dress! i got it right a...
# 2004   I ordered these leggings and loved them, for a...
# 14204  I purchased this jacket in my usual size s, bu...
# 2229   My husband bought this for my birthday. i love...
# 2136   Just like the afterward lace cardigan i love t...
# 8512   This is my favorite shirt ever. i've had it fo...
# 11088  This sweater is the best sweater to throw on o...
# 13102  I'm 5'9 and wear a size 12. this dress runs tt...
# 13800  I actually saw angela from the tv show bones w...
# 5855   I love this dress, but have found that this br...
# 9756   These pants have a really cute design. however...
#
#        Positive Feedback Count   Division Name Department Name      Class Name
# 670                          0         General            Tops           Knits
# 23                           0         General            Tops        Sweaters
# 4833                         0         General            Tops        Sweaters
# 17913                        0         General         Jackets       Outerwear
# 15259                        0         General         Bottoms           Jeans
# 12145                        0         General         Bottoms           Jeans
# 8702                         0         General            Tops           Knits
# 5502                         0         General         Dresses         Dresses
# 15827                        0         General         Dresses         Dresses
# 6482                         0         General         Dresses         Dresses
# 2004                         0  General Petite         Bottoms           Jeans
# 14204                        0         General         Jackets       Outerwear
# 2229                         0         General         Dresses         Dresses
# 2136                         0  General Petite            Tops      Fine gauge
# 8512                         0         General            Tops           Knits
# 11088                        0         General            Tops           Knits
# 13102                        0         General         Dresses         Dresses
# 13800                        0  General Petite         Dresses         Dresses
# 5855                         0  General Petite         Dresses         Dresses
# 9756                         0         General         Bottoms  Casual bottoms

# %%
X.sort_values('Clothing ID').tail(20)
# Out:
#        Clothing ID  Age                                           Title  \
# 2958          1195   45                                       Not great
# 1516          1197   60          Most comfortable fabric i've ever worn
# 1508          1197   68                       Perfect every day neutral
# 1520          1197   55                        Flattering and versatile
# 15385         1198   25                                Comfy and casual
# 15369         1198   68                                  Cute and comfy
# 5510          1199   31                                 Flowy and light
# 11825         1200   24  Its worth the sale price if you know your size
# 4928          1202   45                               Armholes are huge
# 4924          1202   31                                Bright and happy
# 4960          1202   48                                  Pretty but big
# 4965          1202   65                                            Nice
# 4968          1202   55                                       Striking!
# 4936          1202   44                                      Nice print
# 4971          1202   32                           Fabulously easy dress
# 4933          1202   30                                     Great dress
# 4934          1202   28                             A bit like a muumuu
# 897           1204   39                            Comfy and cute pants
# 898           1204   39                        Very comfortable/relaxed
# 13460         1205   34                                       Great fit
#
#                                              Review Text  \
# 2958   The fabric is very thin. it isn't see through,...
# 1516   I originally bought this dress in another colo...
# 1508   So glad i ordered this dress. it fits true to ...
# 1520   I ordered this winth some trepidation as the d...
# 15385  I wanted to love this dress so much! but unfor...
# 15369  This is a great every day dress. the buttons i...
# 5510   This dress in orange is lovely. it's very ligh...
# 11825  Bought this dress without trying it on but lis...
# 4928   The material of the dress is gorgeous, but the...
# 4924   The colors are amazing. so vibrant and plentif...
# 4960   Order a whole size down and this may work. i'm...
# 4965   Beautiful dress, i like the length and cut. ni...
# 4968   I got lots of compliments on this dress as exp...
# 4936   This is a pretty dress, but it runs at least o...
# 4971   I'm taking this to hawaii for the holidays, i'...
# 4933   This dress is very well made. the fabric is th...
# 4934   The fabric on this dress is gorgeous. i wish i...
# 897    I love these pants. i have them in navy and ca...
# 898    These are super soft and relaxed. i have them ...
# 13460  I'm normally a 12/14 and ordered my normal siz...
#
#        Positive Feedback Count   Division Name Department Name Class Name
# 2958                         0         General         Dresses    Dresses
# 1516                         0         General         Dresses    Dresses
# 1508                         1         General         Dresses    Dresses
# 1520                         0         General         Dresses    Dresses
# 15385                        0         General         Dresses    Dresses
# 15369                        0         General         Dresses    Dresses
# 5510                         0  General Petite         Dresses    Dresses
# 11825                        0         General         Dresses    Dresses
# 4928                         1  General Petite         Dresses    Dresses
# 4924                         0  General Petite         Dresses    Dresses
# 4960                         0  General Petite         Dresses    Dresses
# 4965                         1  General Petite         Dresses    Dresses
# 4968                         0  General Petite         Dresses    Dresses
# 4936                         2  General Petite         Dresses    Dresses
# 4971                         0  General Petite         Dresses    Dresses
# 4933                         0  General Petite         Dresses    Dresses
# 4934                         0  General Petite         Dresses    Dresses
# 897                          3  General Petite         Bottoms      Pants
# 898                          0  General Petite         Bottoms      Pants
# 13460                        0         General         Bottoms      Pants

# %% [markdown]
# Clothing ID doesn't seem to be a charaterizing feature, but maybe the model finds a relationship.

# %% [markdown]
# ### Looking at Text Features

# %%
X['Review Text'][50]
# Out:
# "I have a short torso and this works well for me. 34c, bought the 0. there's not much stretch to the fabric so it is fitted to my chest, but not in an uncomfortable way. definitely doesn't hang and have extra fabric like on the model. \r\n\r\nzipper goes almost all the way down to the bottom so it's easier to get on and off which makes up for the lack of stretch n the fabric.\r\n\r\nunlike another reviewer, i found it went really well with navy pants and i wore it to a business meeting under a blazer. wi"

# %%
X['Review Text'][1001]
# Out:
# "I fell in love with this dress when i saw it in the catalog and ordered it immediately. i was a bit disappointed that the dress is a little lighter than the pink showed in the catalog but it didn't deter my liking it because it's still a lovely shade of pink. the fabric takes a bit getting used to though - i thought it would be silkier but it's really a thicker fabric. i ordered a size small and i usually wear size 4. the dress drowned me. so i returned it for an xs, which fit me beautifully. so"

# %%
X['Review Text'][1250]
# Out:
# "Such a beautiful print. i sized up to a 14 because it looked like it has a high waist and it does. the waist comes almost to my bra line. unfortunately, there's a huge amount of fabric and it swallowed me. not slimming at all. i felt like i was wearing a curtain.  i loved the slits in the photo but due to the amount of fabric they weren't visible. i'm short and this literally pooled on the ground a few inches. if you're tall and thin, this is a beauty."

# %%
X['Review Text'][910]
# Out:
# 'I am 5\'-7" and 135 lbs, i bought a medium petite as i wanted the dress to hit at my knees, instead of midi. this dress is easily 2 sizes bigger than expected. the pattern was not flattering on my although i\'m sure it would be for others. i was happy with the length...'

# %%
X['Review Text'][130]
# Out:
# 'I like this sweater so much i just bought it in a second color! the pleats make the sweater conform to my shape just enough to be flattering. i wore it over three different dresses this week that might have felt too bare for work or cooler weather. i live in a hot climate so this is the right weight for our cooler months. the metallic threads give it a little bit of flair and the grey color goes with everything. i\'m 5\'7" size 10-12 and the large fit just right.'

# %% [markdown]
# ## Building Pipeline

# %% [markdown]
# ### Split Features in Numerical, Categorical and Text Features

# %%
num_features = (
    X[[
        'Positive Feedback Count',
        'Age',
    ]].columns
)
print('Numerical features:', num_features)

cat_features = (
    X[[
        'Division Name',
        'Department Name',
        'Class Name',
        'Clothing ID', # more a categorical feature than a numerical feature
    ]].columns
)
print('Categorical features:', cat_features)


text_feature_reviewtext = (
    X[[
        'Review Text',
    ]].columns
)
print ('Review Text feature:', text_feature_reviewtext)

text_feature_title = (
    X[[
        'Title',
    ]].columns
)
print ('Title text feature:', text_feature_title)
# Out:
# Numerical features: Index(['Positive Feedback Count', 'Age'], dtype='object')
# Categorical features: Index(['Division Name', 'Department Name', 'Class Name', 'Clothing ID'], dtype='object')
# Review Text feature: Index(['Review Text'], dtype='object')
# Title text feature: Index(['Title'], dtype='object')

# %% [markdown]
# ### Numerical Feature Pipeline

# %%
num_pipeline = Pipeline([
    (
        'scaler',
        MinMaxScaler(),
    ),
])

num_pipeline
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler())])

# %% [markdown]
# ### Categorical Feature Pipeline

# %%
cat_pipeline = Pipeline([
    (
        'cat_encoder',
        OneHotEncoder(
            sparse_output=False,
            handle_unknown='ignore',
        )
    ),
])

cat_pipeline
# Out:
# Pipeline(steps=[('cat_encoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

# %% [markdown]
# ### Text Feature Pipeline

# %% [markdown]
# #### Tfidf Pipeline

# %%
# Spacy Lemmatizer
class SpacyLemmatizer(BaseEstimator, TransformerMixin):
    def __init__(self):
        return None

    def fit(self, X, y=None):
        return self

    def transform(self, X):

        if not Doc.has_extension("blob"):
            Doc.set_extension("blob", default=None)

        # Load and initialize within the method
        nlp = spacy.load("en_core_web_sm")
        nlp.add_pipe("spacytextblob")


        lemmatized = [
            ' '.join(
                token.lemma_ for token in doc
                if not token.is_stop
            )
            for doc in nlp.pipe(X)
        ]
        return lemmatized

# %%
tfidf_pipeline = Pipeline([
    (
        'dimension_reshaper',
        FunctionTransformer(
            np.reshape,
            kw_args={'newshape':-1},
        ),
    ),
    (
        'lemmatizer',
        SpacyLemmatizer(),
    ),
    (
        'tfidf_vectorizer',
        TfidfVectorizer(
            stop_words='english',
        ),
    ),
])
tfidf_pipeline
# Out:
# Pipeline(steps=[('dimension_reshaper',
#                  FunctionTransformer(func=<function reshape at 0x79b3f8938d70>,
#                                      kw_args={'newshape': -1})),
#                 ('lemmatizer', SpacyLemmatizer()),
#                 ('tfidf_vectorizer', TfidfVectorizer(stop_words='english'))])

# %% [markdown]
# #### Sentiment Pipeline

# %%
class SpacySentimenter(BaseEstimator, TransformerMixin):
    def __init__(self):
        return None

    def fit(self, X, y=None):
        return self

    def transform(self, X):

        if not Doc.has_extension("blob"):
            Doc.set_extension("blob", default=None)

        # Load and initialize within the method
        nlp = spacy.load("en_core_web_sm")
        nlp.add_pipe("spacytextblob")

        # if X is a dataframe with exactly one column
        if isinstance(X, pd.DataFrame):
            if X.shape[1] != 1:
                raise ValueError("Expected DataFrame with a single column")
            X = X.iloc[:, 0]

        # if X a 2d-array
        elif isinstance(X, np.ndarray):
            if X.ndim == 2 and X.shape[1] == 1:
                X = X[:, 0]
            elif X.ndim > 1:
                raise ValueError("Expected 1D array or 2D array with one column")

        sentiment_scores = X.apply(lambda text: nlp(text)._.blob.polarity)
        return np.array(sentiment_scores).reshape(-1, 1)

# %%
sentiment_pipeline = Pipeline([
    (
        'sentimenter',
        SpacySentimenter(),
    ),
])
sentiment_pipeline
# Out:
# Pipeline(steps=[('sentimenter', SpacySentimenter())])

# %% [markdown]
# #### Text Feature Union

# %%
feature_engineering = FeatureUnion([
    ('tfidf', tfidf_pipeline),
    ('sentiment', sentiment_pipeline),
])

text_pipeline = Pipeline([
    (
        'feature_engineering',
        feature_engineering,
    ),
])
text_pipeline
# Out:
# Pipeline(steps=[('feature_engineering',
#                  FeatureUnion(transformer_list=[('tfidf',
#                                                  Pipeline(steps=[('dimension_reshaper',
#                                                                   FunctionTransformer(func=<function reshape at 0x79b3f8938d70>,
#                                                                                       kw_args={'newshape': -1})),
#                                                                  ('lemmatizer',
#                                                                   SpacyLemmatizer()),
#                                                                  ('tfidf_vectorizer',
#                                                                   TfidfVectorizer(stop_words='english'))])),
#                                                 ('sentiment',
#                                                  Pipeline(steps=[('sentimenter',
#                                                                   SpacySentimenter())]))]))])

# %% [markdown]
# ### Build Whole Pipeline

# %%
from sklearn.compose import ColumnTransformer

whole_pipeline = ColumnTransformer([
        ('num', num_pipeline, num_features),
        ('cat', cat_pipeline, cat_features),
        ('tfidf_text_review', text_pipeline, text_feature_reviewtext),
        ('tfidf_text_title', text_pipeline, text_feature_title),
])

whole_pipeline
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('scaler', MinMaxScaler())]),
#                                  Index(['Positive Feedback Count', 'Age'], dtype='object')),
#                                 ('cat',
#                                  Pipeline(steps=[('cat_encoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  Index(['Division Name', 'Department Name', 'Class Name', 'Clothing ID'], dtype='object')),
#                                 ('tfidf_text_review',
#                                  Pipeline(...
#                                                   FeatureUnion(transformer_list=[('tfidf',
#                                                                                   Pipeline(steps=[('dimension_reshaper',
#                                                                                                    FunctionTransformer(func=<function reshape at 0x79b3f8938d70>,
#                                                                                                                        kw_args={'newshape': -1})),
#                                                                                                   ('lemmatizer',
#                                                                                                    SpacyLemmatizer()),
#                                                                                                   ('tfidf_vectorizer',
#                                                                                                    TfidfVectorizer(stop_words='english'))])),
#                                                                                  ('sentiment',
#                                                                                   Pipeline(steps=[('sentimenter',
#                                                                                                    SpacySentimenter())]))]))]),
#                                  Index(['Title'], dtype='object'))])

# %% [markdown]
# ## Training Pipeline

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.pipeline import make_pipeline

# import sklearn
# sklearn.set_config(enable_metadata_routing=True)

model_pipeline = make_pipeline(
    whole_pipeline,
    RandomForestClassifier(random_state=27),
)

model_pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['Positive Feedback Count', 'Age'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('cat_encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   Index(['Division Name', 'Department Name', 'Class Name', 'Clothing ID'], dtype='obj...
#                                                                                                                     FunctionTransformer(func=<function reshape at 0x79b3f8938d70>,
#                                                                                                                                         kw_args={'newshape': -1})),
#                                                                                                                    ('lemmatizer',
#                                                                                                                     SpacyLemmatizer()),
#                                                                                                                    ('tfidf_vectorizer',
#                                                                                                                     TfidfVectorizer(stop_words='english'))])),
#                                                                                                   ('sentiment',
#                                                                                                    Pipeline(steps=[('sentimenter',
#                                                                                                                     SpacySentimenter())]))]))]),
#                                                   Index(['Title'], dtype='object'))])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=27))])

# %%
model_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['Positive Feedback Count', 'Age'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('cat_encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   Index(['Division Name', 'Department Name', 'Class Name', 'Clothing ID'], dtype='obj...
#                                                                                                                     FunctionTransformer(func=<function reshape at 0x79b3f8938d70>,
#                                                                                                                                         kw_args={'newshape': -1})),
#                                                                                                                    ('lemmatizer',
#                                                                                                                     SpacyLemmatizer()),
#                                                                                                                    ('tfidf_vectorizer',
#                                                                                                                     TfidfVectorizer(stop_words='english'))])),
#                                                                                                   ('sentiment',
#                                                                                                    Pipeline(steps=[('sentimenter',
#                                                                                                                     SpacySentimenter())]))]))]),
#                                                   Index(['Title'], dtype='object'))])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=27))])

# %%
model_pipeline.feature_names_in_
# Out:
# array(['Clothing ID', 'Age', 'Title', 'Review Text',
#        'Positive Feedback Count', 'Division Name', 'Department Name',
#        'Class Name'], dtype=object)

# %% [markdown]
# ### Evaluate Model

# %%
y_pred_pipeline = model_pipeline.predict(X_test)
accuracy_pipeline = accuracy_score(y_test, y_pred_pipeline)
precision_pipeline = precision_score(y_test, y_pred_pipeline)
recall_pipeline = recall_score(y_test, y_pred_pipeline)
f1_pipeline = f1_score(y_test, y_pred_pipeline)

print('Accuracy:', accuracy_pipeline)
print('Precision:', precision_pipeline)
print('Recall:', recall_pipeline)
print('F1:', f1_pipeline)
# Out:
# /home/max/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# Accuracy: 0.8688346883468835
# Precision: 0.8717948717948718
# Recall: 0.9855072463768116
# F1: 0.9251700680272109

# %% [markdown]
# ## Fine-Tuning Pipeline

# %% [markdown]
# ### Get Tunable Features

# %%
list(model_pipeline.get_params().keys())
# Out:
# ['memory',
#  'steps',
#  'transform_input',
#  'verbose',
#  'columntransformer',
#  'randomforestclassifier',
#  'columntransformer__force_int_remainder_cols',
#  'columntransformer__n_jobs',
#  'columntransformer__remainder',
#  'columntransformer__sparse_threshold',
#  'columntransformer__transformer_weights',
#  'columntransformer__transformers',
#  'columntransformer__verbose',
#  'columntransformer__verbose_feature_names_out',
#  'columntransformer__num',
#  'columntransformer__cat',
#  'columntransformer__tfidf_text_review',
#  'columntransformer__tfidf_text_title',
#  'columntransformer__num__memory',
#  'columntransformer__num__steps',
#  'columntransformer__num__transform_input',
#  'columntransformer__num__verbose',
#  'columntransformer__num__scaler',
#  'columntransformer__num__scaler__clip',
#  'columntransformer__num__scaler__copy',
#  'columntransformer__num__scaler__feature_range',
#  'columntransformer__cat__memory',
#  'columntransformer__cat__steps',
#  'columntransformer__cat__transform_input',
#  'columntransformer__cat__verbose',
#  'columntransformer__cat__cat_encoder',
#  'columntransformer__cat__cat_encoder__categories',
#  'columntransformer__cat__cat_encoder__drop',
#  'columntransformer__cat__cat_encoder__dtype',
#  'columntransformer__cat__cat_encoder__feature_name_combiner',
#  'columntransformer__cat__cat_encoder__handle_unknown',
#  'columntransformer__cat__cat_encoder__max_categories',
#  'columntransformer__cat__cat_encoder__min_frequency',
#  'columntransformer__cat__cat_encoder__sparse_output',
#  'columntransformer__tfidf_text_review__memory',
#  'columntransformer__tfidf_text_review__steps',
#  'columntransformer__tfidf_text_review__transform_input',
#  'columntransformer__tfidf_text_review__verbose',
#  'columntransformer__tfidf_text_review__feature_engineering',
#  'columntransformer__tfidf_text_review__feature_engineering__n_jobs',
#  'columntransformer__tfidf_text_review__feature_engineering__transformer_list',
#  'columntransformer__tfidf_text_review__feature_engineering__transformer_weights',
#  'columntransformer__tfidf_text_review__feature_engineering__verbose',
#  'columntransformer__tfidf_text_review__feature_engineering__verbose_feature_names_out',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf',
#  'columntransformer__tfidf_text_review__feature_engineering__sentiment',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__memory',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__steps',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__transform_input',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__verbose',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__dimension_reshaper',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__lemmatizer',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__dimension_reshaper__accept_sparse',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__dimension_reshaper__check_inverse',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__dimension_reshaper__feature_names_out',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__dimension_reshaper__func',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__dimension_reshaper__inv_kw_args',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__dimension_reshaper__inverse_func',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__dimension_reshaper__kw_args',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__dimension_reshaper__validate',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__analyzer',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__binary',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__decode_error',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__dtype',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__encoding',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__input',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__lowercase',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__max_df',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__max_features',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__min_df',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__ngram_range',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__norm',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__preprocessor',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__smooth_idf',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__stop_words',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__strip_accents',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__sublinear_tf',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__token_pattern',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__tokenizer',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__use_idf',
#  'columntransformer__tfidf_text_review__feature_engineering__tfidf__tfidf_vectorizer__vocabulary',
#  'columntransformer__tfidf_text_review__feature_engineering__sentiment__memory',
#  'columntransformer__tfidf_text_review__feature_engineering__sentiment__steps',
#  'columntransformer__tfidf_text_review__feature_engineering__sentiment__transform_input',
#  'columntransformer__tfidf_text_review__feature_engineering__sentiment__verbose',
#  'columntransformer__tfidf_text_review__feature_engineering__sentiment__sentimenter',
#  'columntransformer__tfidf_text_title__memory',
#  'columntransformer__tfidf_text_title__steps',
#  'columntransformer__tfidf_text_title__transform_input',
#  'columntransformer__tfidf_text_title__verbose',
#  'columntransformer__tfidf_text_title__feature_engineering',
#  'columntransformer__tfidf_text_title__feature_engineering__n_jobs',
#  'columntransformer__tfidf_text_title__feature_engineering__transformer_list',
#  'columntransformer__tfidf_text_title__feature_engineering__transformer_weights',
#  'columntransformer__tfidf_text_title__feature_engineering__verbose',
#  'columntransformer__tfidf_text_title__feature_engineering__verbose_feature_names_out',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf',
#  'columntransformer__tfidf_text_title__feature_engineering__sentiment',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__memory',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__steps',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__transform_input',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__verbose',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__dimension_reshaper',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__lemmatizer',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__dimension_reshaper__accept_sparse',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__dimension_reshaper__check_inverse',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__dimension_reshaper__feature_names_out',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__dimension_reshaper__func',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__dimension_reshaper__inv_kw_args',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__dimension_reshaper__inverse_func',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__dimension_reshaper__kw_args',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__dimension_reshaper__validate',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__analyzer',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__binary',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__decode_error',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__dtype',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__encoding',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__input',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__lowercase',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__max_df',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__max_features',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__min_df',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__ngram_range',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__norm',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__preprocessor',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__smooth_idf',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__stop_words',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__strip_accents',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__sublinear_tf',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__token_pattern',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__tokenizer',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__use_idf',
#  'columntransformer__tfidf_text_title__feature_engineering__tfidf__tfidf_vectorizer__vocabulary',
#  'columntransformer__tfidf_text_title__feature_engineering__sentiment__memory',
#  'columntransformer__tfidf_text_title__feature_engineering__sentiment__steps',
#  'columntransformer__tfidf_text_title__feature_engineering__sentiment__transform_input',
#  'columntransformer__tfidf_text_title__feature_engineering__sentiment__verbose',
#  'columntransformer__tfidf_text_title__feature_engineering__sentiment__sentimenter',
#  'randomforestclassifier__bootstrap',
#  'randomforestclassifier__ccp_alpha',
#  'randomforestclassifier__class_weight',
#  'randomforestclassifier__criterion',
#  'randomforestclassifier__max_depth',
#  'randomforestclassifier__max_features',
#  'randomforestclassifier__max_leaf_nodes',
#  'randomforestclassifier__max_samples',
#  'randomforestclassifier__min_impurity_decrease',
#  'randomforestclassifier__min_samples_leaf',
#  'randomforestclassifier__min_samples_split',
#  'randomforestclassifier__min_weight_fraction_leaf',
#  'randomforestclassifier__monotonic_cst',
#  'randomforestclassifier__n_estimators',
#  'randomforestclassifier__n_jobs',
#  'randomforestclassifier__oob_score',
#  'randomforestclassifier__random_state',
#  'randomforestclassifier__verbose',
#  'randomforestclassifier__warm_start']

# %%
from sklearn.model_selection import RandomizedSearchCV



my_distributions = dict(
    randomforestclassifier__max_features=[
        100,
        150,
        200,
    ],
    randomforestclassifier__n_estimators=[
        10,
        20,
    ],
    randomforestclassifier__max_depth=[
        5,
        10,
        20,
        # 40,
        # None,
    ],
)

param_search = RandomizedSearchCV(
    estimator=model_pipeline,
    param_distributions=my_distributions,
    n_iter=4,
    cv=4,
    n_jobs=1,
    refit=True,
    verbose=3,
    random_state=27,
    # error_score='raise',
)

param_search.fit(X_train, y_train)

# Retrieve the best parameters
param_search.best_params_
# Out:
# Fitting 4 folds for each of 4 candidates, totalling 16 fits
# /home/max/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# [CV 1/4] END randomforestclassifier__max_depth=10, randomforestclassifier__max_features=100, randomforestclassifier__n_estimators=20;, score=0.815 total time=12.2min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 80
#      39 """
#      40 my_distributions = dict(
#      41     randomforestclassifier__max_depth=[
#    (...)     64     ],
#      65 """
#      68 param_search = RandomizedSearchCV(
#      69     estimator=model_pipeline,
#      70     param_distributions=my_distributions,
#    (...)     77     # error_score='raise',
#      78 )
# ---> 80 param_search.fit(X_train, y_train)
#      82 # Retrieve the best parameters
#      83 param_search.best_params_
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1951, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1949 def _run_search(self, evaluate_candidates):
#    1950     """Search n_iter candidates from param_distributions"""
# -> 1951     evaluate_candidates(
#    1952         ParameterSampler(
#    1953             self.param_distributions, self.n_iter, random_state=self.random_state
#    1954         )
#    1955     )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:866, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     864         estimator.fit(X_train, **fit_params)
#     865     else:
# --> 866         estimator.fit(X_train, y_train, **fit_params)
#     868 except Exception:
#     869     # Note fit time as time until error
#     870     fit_time = time.time() - start_time
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:654, in Pipeline.fit(self, X, y, **params)
#     647     raise ValueError(
#     648         "The `transform_input` parameter can only be set if metadata "
#     649         "routing is enabled. You can enable metadata routing using "
#     650         "`sklearn.set_config(enable_metadata_routing=True)`."
#     651     )
#     653 routed_params = self._check_method_params(method="fit", props=params)
# --> 654 Xt = self._fit(X, y, routed_params, raw_params=params)
#     655 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     656     if self._final_estimator != "passthrough":
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:588, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     581 # Fit or load from cache the current transformer
#     582 step_params = self._get_metadata_for_step(
#     583     step_idx=step_idx,
#     584     step_params=routed_params[name],
#     585     all_params=raw_params,
#     586 )
# --> 588 X, fitted_transformer = fit_transform_one_cached(
#     589     cloned_transformer,
#     590     X,
#     591     y,
#     592     weight=None,
#     593     message_clsname="Pipeline",
#     594     message=self._log_message(step_idx),
#     595     params=step_params,
#     596 )
#     597 # Replace the transformer of the step with the fitted
#     598 # transformer. This is necessary when loading the transformer
#     599 # from the cache.
#     600 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/joblib/memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:1551, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1549 with _print_elapsed_time(message_clsname, message):
#    1550     if hasattr(transformer, "fit_transform"):
# -> 1551         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552     else:
#    1553         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1554             X, **params.get("transform", {})
#    1555         )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:1001, in ColumnTransformer.fit_transform(self, X, y, **params)
#     998 else:
#     999     routed_params = self._get_empty_routing()
# -> 1001 result = self._call_func_on_transformers(
#    1002     X,
#    1003     y,
#    1004     _fit_transform_one,
#    1005     column_as_labels=False,
#    1006     routed_params=routed_params,
#    1007 )
#    1009 if not result:
#    1010     self._update_fitted_transformers([])
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:910, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     898             extra_args = {}
#     899         jobs.append(
#     900             delayed(func)(
#     901                 transformer=clone(trans) if not fitted else trans,
#    (...)    907             )
#     908         )
# --> 910     return Parallel(n_jobs=self.n_jobs)(jobs)
#     912 except ValueError as e:
#     913     if "Expected 2D array, got 1D array instead" in str(e):
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:1551, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1549 with _print_elapsed_time(message_clsname, message):
#    1550     if hasattr(transformer, "fit_transform"):
# -> 1551         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552     else:
#    1553         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1554             X, **params.get("transform", {})
#    1555         )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:730, in Pipeline.fit_transform(self, X, y, **params)
#     724 last_step_params = self._get_metadata_for_step(
#     725     step_idx=len(self) - 1,
#     726     step_params=routed_params[self.steps[-1][0]],
#     727     all_params=params,
#     728 )
#     729 if hasattr(last_step, "fit_transform"):
# --> 730     return last_step.fit_transform(
#     731         Xt, y, **last_step_params["fit_transform"]
#     732     )
#     733 else:
#     734     return last_step.fit(Xt, y, **last_step_params["fit"]).transform(
#     735         Xt, **last_step_params["transform"]
#     736     )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:1974, in FeatureUnion.fit_transform(self, X, y, **params)
#    1971             routed_params[name] = Bunch(transform={})
#    1972             routed_params[name].fit = params
# -> 1974 results = self._parallel_func(X, y, _fit_transform_one, routed_params)
#    1975 if not results:
#    1976     # All transformers are None
#    1977     return np.zeros((X.shape[0], 0))
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:1996, in FeatureUnion._parallel_func(self, X, y, func, routed_params)
#    1993 self._validate_transformer_weights()
#    1994 transformers = list(self._iter())
# -> 1996 return Parallel(n_jobs=self.n_jobs)(
#    1997     delayed(func)(
#    1998         transformer,
#    1999         X,
#    2000         y,
#    2001         weight,
#    2002         message_clsname="FeatureUnion",
#    2003         message=self._log_message(name, idx, len(transformers)),
#    2004         params=routed_params[name],
#    2005     )
#    2006     for idx, (name, transformer, weight) in enumerate(transformers, 1)
#    2007 )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:1551, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1549 with _print_elapsed_time(message_clsname, message):
#    1550     if hasattr(transformer, "fit_transform"):
# -> 1551         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552     else:
#    1553         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1554             X, **params.get("transform", {})
#    1555         )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:718, in Pipeline.fit_transform(self, X, y, **params)
#     679 """Fit the model and transform with the final estimator.
#     680
#     681 Fit all the transformers one after the other and sequentially transform
#    (...)    715     Transformed samples.
#     716 """
#     717 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 718 Xt = self._fit(X, y, routed_params)
#     720 last_step = self._final_estimator
#     721 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:588, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     581 # Fit or load from cache the current transformer
#     582 step_params = self._get_metadata_for_step(
#     583     step_idx=step_idx,
#     584     step_params=routed_params[name],
#     585     all_params=raw_params,
#     586 )
# --> 588 X, fitted_transformer = fit_transform_one_cached(
#     589     cloned_transformer,
#     590     X,
#     591     y,
#     592     weight=None,
#     593     message_clsname="Pipeline",
#     594     message=self._log_message(step_idx),
#     595     params=step_params,
#     596 )
#     597 # Replace the transformer of the step with the fitted
#     598 # transformer. This is necessary when loading the transformer
#     599 # from the cache.
#     600 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/joblib/memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:1551, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1549 with _print_elapsed_time(message_clsname, message):
#    1550     if hasattr(transformer, "fit_transform"):
# -> 1551         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552     else:
#    1553         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1554             X, **params.get("transform", {})
#    1555         )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/base.py:921, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     918     return self.fit(X, **fit_params).transform(X)
#     919 else:
#     920     # fit method of arity 2 (supervised transformation)
# --> 921     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# Cell In[19], line 19, in SpacyLemmatizer.transform(self, X)
#      15 nlp = spacy.load("en_core_web_sm")
#      16 nlp.add_pipe("spacytextblob")
# ---> 19 lemmatized = [
#      20     ' '.join(
#      21         token.lemma_ for token in doc
#      22         if not token.is_stop
#      23     )
#      24     for doc in nlp.pipe(X)
#      25 ]
#      26 return lemmatized
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/language.py:1621, in Language.pipe(self, texts, as_tuples, batch_size, disable, component_cfg, n_process)
#    1619     for pipe in pipes:
#    1620         docs = pipe(docs)
# -> 1621 for doc in docs:
#    1622     yield doc
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/util.py:1713, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1711     if arg in kwargs:
#    1712         kwargs.pop(arg)
# -> 1713 for doc in docs:
#    1714     try:
#    1715         doc = proc(doc, **kwargs)  # type: ignore[call-arg]
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/util.py:1703, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1693 def _pipe(
#    1694     docs: Iterable["Doc"],
#    1695     proc: "PipeCallable",
#    (...)   1700     kwargs: Mapping[str, Any],
#    1701 ) -> Iterator["Doc"]:
#    1702     if hasattr(proc, "pipe"):
# -> 1703         yield from proc.pipe(docs, **kwargs)
#    1704     else:
#    1705         # We added some args for pipe that __call__ doesn't expect.
#    1706         kwargs = dict(kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/pipeline/transition_parser.pyx:245, in pipe()
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/util.py:1650, in minibatch(items, size)
#    1648 while True:
#    1649     batch_size = next(size_)
# -> 1650     batch = list(itertools.islice(items, int(batch_size)))
#    1651     if len(batch) == 0:
#    1652         break
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/util.py:1703, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1693 def _pipe(
#    1694     docs: Iterable["Doc"],
#    1695     proc: "PipeCallable",
#    (...)   1700     kwargs: Mapping[str, Any],
#    1701 ) -> Iterator["Doc"]:
#    1702     if hasattr(proc, "pipe"):
# -> 1703         yield from proc.pipe(docs, **kwargs)
#    1704     else:
#    1705         # We added some args for pipe that __call__ doesn't expect.
#    1706         kwargs = dict(kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/pipeline/pipe.pyx:55, in pipe()
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/util.py:1703, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1693 def _pipe(
#    1694     docs: Iterable["Doc"],
#    1695     proc: "PipeCallable",
#    (...)   1700     kwargs: Mapping[str, Any],
#    1701 ) -> Iterator["Doc"]:
#    1702     if hasattr(proc, "pipe"):
# -> 1703         yield from proc.pipe(docs, **kwargs)
#    1704     else:
#    1705         # We added some args for pipe that __call__ doesn't expect.
#    1706         kwargs = dict(kwargs)
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/pipeline/pipe.pyx:57, in pipe()
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/pipeline/attributeruler.py:142, in AttributeRuler.__call__(self, doc)
#     140 error_handler = self.get_error_handler()
#     141 try:
# --> 142     matches = self.match(doc)
#     143     self.set_annotations(doc, matches)
#     144     return doc
#
# File ~/Desktop/20250219_Udacity_Nanodegree_Data_Scientist/dsnd-pipelines-project/.venv/lib/python3.12/site-packages/spacy/pipeline/attributeruler.py:149, in AttributeRuler.match(self, doc)
#     148 def match(self, doc: Doc):
# --> 149     matches = self.matcher(doc, allow_missing=True, as_spans=False)
#     150     # Sort by the attribute ID, so that later rules have precedence
#     151     matches = [
#     152         (int(self.vocab.strings[m_id]), m_id, s, e) for m_id, s, e in matches  # type: ignore
#     153     ]
#
# KeyboardInterrupt:

# %%
model_best = param_search.best_estimator_
model_best

# %%
y_pred_model_best_pipeline = model_best.predict(X_test)
accuracy_best_model_pipeline = accuracy_score(y_test, y_pred_model_best_pipeline)
precision_best_model_pipeline = precision_score(y_test, y_pred_model_best_pipeline)
recall_best_model_pipeline = recall_score(y_test, y_pred_model_best_pipeline)
f1_best_model_pipeline = f1_score(y_test, y_pred_model_best_pipeline)

print('Accuracy:', accuracy_best_model_pipeline)
print('Precision:', precision_best_model_pipeline)
print('Recall:', recall_best_model_pipeline)
print('F1:', f1_best_model_pipeline)
